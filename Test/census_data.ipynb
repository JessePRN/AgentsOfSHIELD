# %%
#dependencies 
import pandas as pd
import matplotlib.pyplot as plt

# %%
# file paths
path_2017= pd.read_csv("Resources_csv/2017_all_metro_micro_GA.csv",delimiter=',')
path_2018= pd.read_csv("Resources_csv/2018_all_metro_micro_GA.csv",delimiter=',')
path_2019= pd.read_csv("Resources_csv/2019_all_metro_micro_GA.csv",delimiter=',')
path_2020= pd.read_csv("Resources_csv/2020_all_metro_micro_GA.csv",delimiter=',')

path_2017.head()
# Out:
#             Unnamed: 0            Albany, GA Metro Area  \
# 0     Label (Grouping)  Albany, GA Metro Area!!Estimate
# 1               Total:                          151,841
# 2         1 to 4 years                            8,273
# 3        5 to 17 years                           27,915
# 4      18 and 19 years                            4,686
#
#                                Unnamed: 2            Americus, GA Micro Area  \
# 0  Albany, GA Metro Area!!Margin of Error  Americus, GA Micro Area!!Estimate
# 1                                    ±294                             35,350
# 2                                    ±296                              1,712
# 3                                    ±154                              6,321
# 4                                    ±210                              1,315
#
#                                  Unnamed: 4  \
# 0  Americus, GA Micro Area!!Margin of Error
# 1                                      ±142
# ...

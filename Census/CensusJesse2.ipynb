# %%
file_3 = "gz_2010_us_050_00_500k.json"
file_3_df = pd.read_json(file_3)
file_3_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/pr/1_6x41cj4bg9v9n2y7ppnzyc0000gn/T/ipykernel_57083/3263425417.py in <module>
#       1 file_3 = "gz_2010_us_050_00_500k.json"
# ----> 2 file_3_df = pd.read_json(file_3)
#       3 file_3_df
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     612
#     613     with json_reader:
# --> 614         return json_reader.read()
#     615
#     616
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/json/_json.py in read(self)
#     746                 obj = self._get_object_parser(self._combine_lines(data_lines))
#     747         else:
# --> 748             obj = self._get_object_parser(self.data)
#     749         self.close()
#     750         return obj
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     768         obj = None
#     769         if typ == "frame":
# --> 770             obj = FrameParser(json, **kwargs).parse()
#     771
#     772         if typ == "series" or obj is None:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/json/_json.py in parse(self)
#     883
#     884         else:
# --> 885             self._parse_no_numpy()
#     886
#     887         if self.obj is None:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/json/_json.py in _parse_no_numpy(self)
#    1138         if orient == "columns":
#    1139             self.obj = DataFrame(
# -> 1140                 loads(json, precise_float=self.precise_float), dtype=None
#    1141             )
#    1142         elif orient == "split":
#
# ValueError: Expected object or value

# %%
# Dependencies
import pandas as pd
import random
import matplotlib.pyplot as plt
import numpy as np
import math


file_1 = "co-est2021-pop-13.csv"
file_2 = "co-est2020-alldata.csv"

file_1_df = pd.read_csv(file_1, delimiter=",", skiprows=3)

file_1_df.tail(10)
recent_census =file_1_df.drop(range(160,165))
recent_census
# Out:
#                      Unnamed: 0  Unnamed: 1        2020        2021
# 0                       Georgia  10,711,908  10,725,800  10,799,566
# 1      .Appling County, Georgia      18,444      18,428      18,488
# 2     .Atkinson County, Georgia       8,286       8,301       8,391
# 3        .Bacon County, Georgia      11,140      11,123      11,079
# 4        .Baker County, Georgia       2,876       2,844       2,819
# ..                          ...         ...         ...         ...
# 155  .Whitfield County, Georgia     102,864     102,727     102,848
# 156     .Wilcox County, Georgia       8,766       8,731       8,739
# 157     .Wilkes County, Georgia       9,565       9,556       9,513
# 158  .Wilkinson County, Georgia       8,877       8,844       8,831
# 159      .Worth County, Georgia      20,784      20,719      20,554
#
# [160 rows x 4 columns]

# %%
#interactive mode
# %matplotlib notebook

# %%
recent_census21 = recent_census['Unnamed: 0'].str.replace('.','')
county21 = recent_census21.str.split(',').str[0]

county21
# Out:
# /Users/jesse/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# 0               Georgia
# 1        Appling County
# 2       Atkinson County
# 3          Bacon County
# 4          Baker County
#              ...
# 155    Whitfield County
# 156       Wilcox County
# 157       Wilkes County
# 158    Wilkinson County
# 159        Worth County
# Name: Unnamed: 0, Length: 160, dtype: object

# %%
# 2021 data
data21 = recent_census[['2020','2021']]

census_20 = pd.to_numeric(data21['2020'].str.replace(',',''), errors = 'coerce')

census_20
# Out:
# 0      10725800
# 1         18428
# 2          8301
# 3         11123
# 4          2844
#          ...
# 155      102727
# 156        8731
# 157        9556
# 158        8844
# 159       20719
# Name: 2020, Length: 160, dtype: int64

# %%
census_21 = pd.to_numeric(recent_census['2021'].str.replace(',',''), errors = 'coerce')

census_21
# Out:
# 0      10799566
# 1         18488
# 2          8391
# 3         11079
# 4          2819
#          ...
# 155      102848
# 156        8739
# 157        9513
# 158        8831
# 159       20554
# Name: 2021, Length: 160, dtype: int64

# %%
organized_21 = pd.DataFrame({"County":county21,"2020":census_20, "2021":census_21 })

census21_df= organized_21.set_index("County")

census21_df
# Out:
#                       2020      2021
# County
# Georgia           10725800  10799566
# Appling County       18428     18488
# Atkinson County       8301      8391
# Bacon County         11123     11079
# Baker County          2844      2819
# ...                    ...       ...
# Whitfield County    102727    102848
# Wilcox County         8731      8739
# Wilkes County         9556      9513
# Wilkinson County      8844      8831
# Worth County         20719     20554
#
# [160 rows x 2 columns]

# %%
file_2_df = pd.read_csv(file_2, delimiter=",", encoding="ISO-8859-1")

# file_2_df
file_2_ga = file_2_df[file_2_df['STNAME'] == 'Georgia']
file_2_ga.to_csv('cleanerCounties.csv')
file_2_ga
# Out:
#      SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME           CTYNAME  \
# 398      40       3         5     13       0  Georgia           Georgia
# 399      50       3         5     13       1  Georgia    Appling County
# 400      50       3         5     13       3  Georgia   Atkinson County
# 401      50       3         5     13       5  Georgia      Bacon County
# 402      50       3         5     13       7  Georgia      Baker County
# ..      ...     ...       ...    ...     ...      ...               ...
# 553      50       3         5     13     313  Georgia  Whitfield County
# 554      50       3         5     13     315  Georgia     Wilcox County
# 555      50       3         5     13     317  Georgia     Wilkes County
# 556      50       3         5     13     319  Georgia  Wilkinson County
# 557      50       3         5     13     321  Georgia      Worth County
#
#     CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RNETMIG2011  \
# 398       9687653            9688737          9712209  ...     3.041427
# 399         18236              18237            18337  ...     3.098163
# 400          8375               8380             8363  ...    -9.329028
# 401         11096              11097            11062  ...     7.833603
# 402          3451               3447             3431  ...   -38.267576
# ..            ...                ...              ...  ...          ...
# 553        102599             102602           102740  ...    -5.533701
# 554          9255               9251             9313  ...    -6.572922
# 555         10593              10593            10389  ...   -13.676706
# 556          9563               9569             9528  ...   -14.360382
# 557         21679              21667            21692  ...    -9.674134
#
#      RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015  RNETMIG2016  \
# 398     3.798407     1.747055     4.060100     5.814395     7.200931
# 399    -9.988871    -4.843669     2.931914    -4.662637    -0.813824
# 400   -18.178535    -4.116970   -14.082797     7.737879   -11.188643
# 401    -5.021971     0.089582     0.715820     1.071285     2.400747
# 402    11.974255    -8.933889   -18.694407   -27.782065    -1.881763
# ..           ...          ...          ...          ...          ...
# 553    -5.965944    -7.713370    -1.963739    -0.193555     1.134970
# 554   -18.889556     1.324284   -14.569315    12.371823   -17.704073
# 555   -12.202923   -10.187775     4.424111     0.301705    -7.600709
# 556     7.303906   -11.569897    -8.581849   -19.495725    -3.425225
# 557    -8.910244   -17.447069    -4.136161   -16.450050    -0.869061
#
#      RNETMIG2017  RNETMIG2018  RNETMIG2019  RNETMIG2020
# 398     5.948622     5.638213     6.502924     4.765012
# 399    -1.626457     4.109774    -8.340780    -2.941657
# 400    -7.009063     6.505632   -16.613495     8.402353
# 401    -9.077964   -10.313901    -2.342976    -7.590133
# 402    -3.468390   -25.932448   -16.297262   -24.592888
# ..           ...          ...          ...          ...
# 553    -7.072937    -4.851221    -1.439719    -7.111897
# 554    -7.380493     4.213163   -21.390374    -8.299725
# 555     9.859728     3.449500    -4.588559    -0.822073
# 556    -5.674864    10.246130    -7.914832    -9.240478
# 557    -8.433501   -10.920933    -2.519016    -6.673805
#
# [160 rows x 180 columns]

# %%
ga_census_estimate_population = file_2_ga[["CTYNAME","POPESTIMATE2010","POPESTIMATE2011","POPESTIMATE2012","POPESTIMATE2013", "POPESTIMATE2014", "POPESTIMATE2015", "POPESTIMATE2016", "POPESTIMATE2017", "POPESTIMATE2018","POPESTIMATE2019"]]
ga_census_estimate_population = ga_census_estimate_population.rename(columns={"CTYNAME":"County","POPESTIMATE2010": "2010", "POPESTIMATE2011": "2011", "POPESTIMATE2012": "2012", "POPESTIMATE2013": "2013", "POPESTIMATE2014": "2014", "POPESTIMATE2015": "2015", "POPESTIMATE2016": "2016", "POPESTIMATE2017": "2017", "POPESTIMATE2018": "2018", "POPESTIMATE2019": "2019"})
ga_census_20 = ga_census_estimate_population.set_index("County")
ga_census_20
# Out:
#                      2010     2011     2012     2013      2014      2015  \
# County
# Georgia           9712209  9803630  9903580  9975592  10071204  10183353
# Appling County      18337    18459    18382    18367     18469     18420
# Atkinson County      8363     8359     8254     8263      8211      8331
# Bacon County        11062    11150    11152    11174     11178     11225
# Baker County         3431     3311     3370     3346      3287      3192
# ...                   ...      ...      ...      ...       ...       ...
# Whitfield County   102740   102909   102926   102691    103039    103621
# Wilcox County        9313     9248     9069     9054      8929      9015
# Wilkes County       10389    10230    10093     9931      9960      9927
# Wilkinson County     9528     9413     9481     9361      9283      9080
# Worth County        21692    21516    21356    21058     21010     20692
#
#                       2016      2017      2018      2019
# County
# Georgia           10308442  10417031  10519389  10628020
# Appling County       18443     18447     18538     18389
# Atkinson County       8293      8257      8344      8269
# Bacon County         11268     11204     11096     11098
# Baker County          3185      3158      3089      3047
# ...                    ...       ...       ...       ...
# Whitfield County    104314    104086    104109    104265
# Wilcox County         8834      8780      8784      8607
# Wilkes County         9808      9868      9845      9769
# Wilkinson County      9021      8953      9005      8936
# Worth County         20732     20532     20307     20185
#
# [160 rows x 10 columns]

# %%
# merge_census = ga_census_20.merge(census21_df,how ='left', on ='CTYNAME')

merge_census_raw = census21_df.merge(ga_census_20,how ='right', on ='County')


column_names = ["2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"]

merge_census = merge_census_raw.reindex(columns=column_names)

merge_census
# Out:
#                      2010     2011     2012     2013      2014      2015  \
# County
# Georgia           9712209  9803630  9903580  9975592  10071204  10183353
# Appling County      18337    18459    18382    18367     18469     18420
# Atkinson County      8363     8359     8254     8263      8211      8331
# Bacon County        11062    11150    11152    11174     11178     11225
# Baker County         3431     3311     3370     3346      3287      3192
# ...                   ...      ...      ...      ...       ...       ...
# Whitfield County   102740   102909   102926   102691    103039    103621
# Wilcox County        9313     9248     9069     9054      8929      9015
# Wilkes County       10389    10230    10093     9931      9960      9927
# Wilkinson County     9528     9413     9481     9361      9283      9080
# Worth County        21692    21516    21356    21058     21010     20692
#
#                       2016      2017      2018      2019      2020      2021
# County
# Georgia           10308442  10417031  10519389  10628020  10725800  10799566
# Appling County       18443     18447     18538     18389     18428     18488
# Atkinson County       8293      8257      8344      8269      8301      8391
# Bacon County         11268     11204     11096     11098     11123     11079
# Baker County          3185      3158      3089      3047      2844      2819
# ...                    ...       ...       ...       ...       ...       ...
# Whitfield County    104314    104086    104109    104265    102727    102848
# Wilcox County         8834      8780      8784      8607      8731      8739
# Wilkes County         9808      9868      9845      9769      9556      9513
# Wilkinson County      9021      8953      9005      8936      8844      8831
# Worth County         20732     20532     20307     20185     20719     20554
#
# [160 rows x 12 columns]

# %%
year_merge = merge_census.keys()
year_merge
# Out:
# Index(['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021'],
#       dtype='object')

# %%
countyDataDictionary_merge = {}
county_names= []

for x in randomNumbers_merge:

    countyDataDictionary_merge[x] = merge_census.iloc[x]        

for x in countyDataDictionary_merge:
    print(countyDataDictionary_merge[x])
    
    county_names.append(countyDataDictionary_merge[x].name)
    plt.plot(year_merge, countyDataDictionary_merge[x])
    
# for col in df:
#     plt.plot(df.index, df[col])
# plt.legend(df.columns)
# plt.show()

county_df = pd.DataFrame({"data":countyDataDictionary_merge})

# print(county_df)

plt.legend(county_names,loc="lower left")
# plt.yscale('log')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/pr/1_6x41cj4bg9v9n2y7ppnzyc0000gn/T/ipykernel_57083/1341939532.py in <module>
#       2 county_names= []
#       3
# ----> 4 for x in randomNumbers_merge:
#       5
#       6     countyDataDictionary_merge[x] = merge_census.iloc[x]
#
# NameError: name 'randomNumbers_merge' is not defined

# %%
merge_census
# Out:
#                      2010     2011     2012     2013      2014      2015  \
# County
# Georgia           9712209  9803630  9903580  9975592  10071204  10183353
# Appling County      18337    18459    18382    18367     18469     18420
# Atkinson County      8363     8359     8254     8263      8211      8331
# Bacon County        11062    11150    11152    11174     11178     11225
# Baker County         3431     3311     3370     3346      3287      3192
# ...                   ...      ...      ...      ...       ...       ...
# Whitfield County   102740   102909   102926   102691    103039    103621
# Wilcox County        9313     9248     9069     9054      8929      9015
# Wilkes County       10389    10230    10093     9931      9960      9927
# Wilkinson County     9528     9413     9481     9361      9283      9080
# Worth County        21692    21516    21356    21058     21010     20692
#
#                       2016      2017      2018      2019      2020      2021
# County
# Georgia           10308442  10417031  10519389  10628020  10725800  10799566
# Appling County       18443     18447     18538     18389     18428     18488
# Atkinson County       8293      8257      8344      8269      8301      8391
# Bacon County         11268     11204     11096     11098     11123     11079
# Baker County          3185      3158      3089      3047      2844      2819
# ...                    ...       ...       ...       ...       ...       ...
# Whitfield County    104314    104086    104109    104265    102727    102848
# Wilcox County         8834      8780      8784      8607      8731      8739
# Wilkes County         9808      9868      9845      9769      9556      9513
# Wilkinson County      9021      8953      9005      8936      8844      8831
# Worth County         20732     20532     20307     20185     20719     20554
#
# [160 rows x 12 columns]

# %%
# grabbing all the urban counties

urban_counties = merge_census.loc[merge_census['2020'] > 50000, :] 
urban_counties = urban_counties.drop(["Georgia"])
# Cobb County        753361   757133   761060   766209   766802
# Columbia County    151757   154399   157129   156773   159639
# Coweta County      143218   146063   148504   146653   149956
# DeKalb County      751680   755514   759932   763831   757718
# Dougherty County    89537    89247    87854    85366    84844
# Douglas County     143563   145260   146680   144497   145814
# Effingham County    60121    62274    64342    65150    66741
# Fayette County     112626   113333   114645   119441   120574
# Floyd County        97459    97907    98325    98593    98771
# Forsyth County     229367   237330   244624   252786   260206
# Fulton County     1039996  1051516  1065019  1069023  1065334
# Glynn County        84836    85099    85326    84470    84739
# Gordon County       57204    57737    58046    57696    58237
# Gwinnett County    918681   928072   937399   957801   964546
# Hall County        198854   201396   204310   203589   207369
# Henry County       225246   229873   234671   241818   245235
# Houston County     152757   155004   157427   164242   166829
# Jackson County      67681    70347    73015    76712    80286
# Liberty County      61819    60887    62813    65220    65711
# Lowndes County     115495   116361   117600   118316   119276
# Muscogee County    193858   194362   196074   206960   205617
# Newton County      107903   109556   111894   112780   115355
# Paulding County    159642   164482   169302   169660   173780
# Richmond County    201965   202027   202639   206328   205673
# Rockdale County     89800    90402    90639    93614    94082
# Spalding County     65348    66092    66835    67413    67909
# Troup County        70123    70091    70059    69388    69720
# Walker County       69087    69507    69769    67711    68510
# Walton County       91389    93450    94818    97135    99853
# Whitfield County   104086   104109   104265   102727   102848

# %%
# grabbing rural counties

rural_counties = merge_census.loc[merge_census['2020'] < 50000, :] 
rural_counties
# Out:
#                    2010   2011   2012   2013   2014   2015   2016   2017  \
# County
# Appling County    18337  18459  18382  18367  18469  18420  18443  18447
# Atkinson County    8363   8359   8254   8263   8211   8331   8293   8257
# Bacon County      11062  11150  11152  11174  11178  11225  11268  11204
# Baker County       3431   3311   3370   3346   3287   3192   3185   3158
# Baldwin County    45703  45178  46522  46191  45920  45566  45260  44993
# ...                 ...    ...    ...    ...    ...    ...    ...    ...
# White County      27201  27401  27626  27831  28025  28389  28793  29429
# Wilcox County      9313   9248   9069   9054   8929   9015   8834   8780
# Wilkes County     10389  10230  10093   9931   9960   9927   9808   9868
# Wilkinson County   9528   9413   9481   9361   9283   9080   9021   8953
# Worth County      21692  21516  21356  21058  21010  20692  20732  20532
#
#                    2018   2019   2020   2021
# County
# Appling County    18538  18389  18428  18488
# Atkinson County    8344   8269   8301   8391
# Bacon County      11096  11098  11123  11079
# Baker County       3089   3047   2844   2819
# Baldwin County    45001  45006  43773  43781
# ...                 ...    ...    ...    ...
# White County      29893  30601  28090  28442
# Wilcox County      8784   8607   8731   8739
# Wilkes County      9845   9769   9556   9513
# Wilkinson County   9005   8936   8844   8831
# Worth County      20307  20185  20719  20554
#
# [118 rows x 12 columns]

# %%
# rural_counties
rural_normalized = rural_counties.pct_change(axis='columns', periods=1)
rural_normalized = rural_normalized.drop(columns=['2010'])
rural_normalized
# Out:
#                       2011      2012      2013      2014      2015      2016  \
# County
# Appling County    0.006653 -0.004171 -0.000816  0.005553 -0.002653  0.001249
# Atkinson County  -0.000478 -0.012561  0.001090 -0.006293  0.014615 -0.004561
# Floyd County      0.007536  0.004597  0.004269  0.002726  0.001805
# Forsyth County    0.038536  0.034717  0.030734  0.033365  0.029353
# Fulton County     0.015804  0.011077  0.012841  0.003760 -0.003451
# Glynn County      0.007422  0.003100  0.002667 -0.010032  0.003185
# Gordon County     0.003315  0.009318  0.005352 -0.006030  0.009377
# Gwinnett County   0.014791  0.010222  0.010050  0.021764  0.007042
# Hall County       0.013651  0.012783  0.014469 -0.003529  0.018567
# Henry County      0.019028  0.020542  0.020872  0.030455  0.014130
# Houston County    0.009717  0.014710  0.015632  0.043290  0.015751
# Jackson County    0.039790  0.039391  0.037926  0.050633  0.046590
# Liberty County    0.002384 -0.015076  0.031632  0.038320  0.007528
# Lowndes County    0.009069  0.007498  0.010648  0.006088  0.008114
# Muscogee County  -0.012712  0.002600  0.008808  0.055520 -0.006489
# Newton County     0.012898  0.015319  0.021341  0.007918  0.022832
# Paulding County   0.027198  0.030318  0.029304  0.002115  0.024284
# Richmond County  -0.001058  0.000307  0.003029  0.018205 -0.003175
# Rockdale County   0.009045  0.006704  0.002622  0.032823  0.004999
# Spalding County   0.012786  0.011385  0.011242  0.008648  0.007358
# Troup County      0.001900 -0.000456 -0.000457 -0.009578  0.004785
# Walker County     0.008437  0.006079  0.003769 -0.029497  0.011800
# Walton County     0.016721  0.022552  0.014639  0.024436  0.027982
# Whitfield County -0.002186  0.000221  0.001498 -0.014751  0.001178

# %%
urban_normalized.mean()
# Out:
# 2011    0.009623
# 2012    0.008546
# 2013    0.007009
# 2014    0.010611
# 2015    0.011152
# 2016    0.012941
# 2017    0.012107
# 2018    0.011670
# 2019    0.012936
# 2020    0.011010
# 2021    0.011023
# dtype: float64

# %%
plt.plot(urban_normalized.mean(),label='Urban')
plt.plot(rural_normalized.mean(),label='Rural')
plt.legend()
plt.show()

# %%
plt.plot(urban_normalized.median(),label='Urban')
plt.plot(rural_normalized.median(),label='Rural')
plt.legend()
plt.show()

# %%
merge_normalized = merge_census.pct_change(axis='columns', periods=1)
merge_normalized
# Out:
#                   2010      2011      2012      2013      2014      2015  \
# County
# Georgia            NaN  0.009413  0.010195  0.007271  0.009585  0.011136
# Appling County     NaN  0.006653 -0.004171 -0.000816  0.005553 -0.002653
# Atkinson County    NaN -0.000478 -0.012561  0.001090 -0.006293  0.014615
# Bacon County       NaN  0.007955  0.000179  0.001973  0.000358  0.004205
# Baker County       NaN -0.034975  0.017819 -0.007122 -0.017633 -0.028902
# ...                ...       ...       ...       ...       ...       ...
# Whitfield County   NaN  0.001645  0.000165 -0.002283  0.003389  0.005648
# Wilcox County      NaN -0.006979 -0.019356 -0.001654 -0.013806  0.009632
# Wilkes County      NaN -0.015305 -0.013392 -0.016051  0.002920 -0.003313
# Wilkinson County   NaN -0.012070  0.007224 -0.012657 -0.008332 -0.021868
# Worth County       NaN -0.008114 -0.007436 -0.013954 -0.002279 -0.015136
#
#                       2016      2017      2018      2019      2020      2021
# County
# Georgia           0.012284  0.010534  0.009826  0.010327  0.009200  0.006877
# Appling County    0.001249  0.000217  0.004933 -0.008038  0.002121  0.003256
# Atkinson County  -0.004561 -0.004341  0.010537 -0.008988  0.003870  0.010842
# Bacon County      0.003831 -0.005680 -0.009639  0.000180  0.002253 -0.003956
# Baker County     -0.002193 -0.008477 -0.021849 -0.013597 -0.066623 -0.008790
# ...                    ...       ...       ...       ...       ...       ...
# Whitfield County  0.006688 -0.002186  0.000221  0.001498 -0.014751  0.001178
# Wilcox County    -0.020078 -0.006113  0.000456 -0.020150  0.014407  0.000916
# Wilkes County    -0.011988  0.006117 -0.002331 -0.007720 -0.021804 -0.004500
# Wilkinson County -0.006498 -0.007538  0.005808 -0.007662 -0.010295 -0.001470
# Worth County      0.001933 -0.009647 -0.010959 -0.006008  0.026455 -0.007964
#
# [160 rows x 12 columns]

# %%
# Get rid of NaN columns
merge_normalized = merge_normalized.drop(columns=['2010'])
# Get rid of Georgia row so it doesn't affect county statistics
merge_normalized = merge_normalized.drop(["Georgia"])

# %%
merge_normalized
# Out:
#                       2011      2012      2013      2014      2015      2016  \
# County
# Appling County    0.006653 -0.004171 -0.000816  0.005553 -0.002653  0.001249
# Atkinson County  -0.000478 -0.012561  0.001090 -0.006293  0.014615 -0.004561
# Bacon County      0.007955  0.000179  0.001973  0.000358  0.004205  0.003831
# Baker County     -0.034975  0.017819 -0.007122 -0.017633 -0.028902 -0.002193
# Baldwin County   -0.011487  0.029749 -0.007115 -0.005867 -0.007709 -0.006716
# ...                    ...       ...       ...       ...       ...       ...
# Whitfield County  0.001645  0.000165 -0.002283  0.003389  0.005648  0.006688
# Wilcox County    -0.006979 -0.019356 -0.001654 -0.013806  0.009632 -0.020078
# Wilkes County    -0.015305 -0.013392 -0.016051  0.002920 -0.003313 -0.011988
# Wilkinson County -0.012070  0.007224 -0.012657 -0.008332 -0.021868 -0.006498
# Worth County     -0.008114 -0.007436 -0.013954 -0.002279 -0.015136  0.001933
#
#                       2017      2018      2019      2020      2021
# County
# Appling County    0.000217  0.004933 -0.008038  0.002121  0.003256
# Atkinson County  -0.004341  0.010537 -0.008988  0.003870  0.010842
# Bacon County     -0.005680 -0.009639  0.000180  0.002253 -0.003956
# Baker County     -0.008477 -0.021849 -0.013597 -0.066623 -0.008790
# Baldwin County   -0.005899  0.000178  0.000111 -0.027396  0.000183
# ...                    ...       ...       ...       ...       ...
# Whitfield County -0.002186  0.000221  0.001498 -0.014751  0.001178
# Wilcox County    -0.006113  0.000456 -0.020150  0.014407  0.000916
# Wilkes County     0.006117 -0.002331 -0.007720 -0.021804 -0.004500
# Wilkinson County -0.007538  0.005808 -0.007662 -0.010295 -0.001470
# Worth County     -0.009647 -0.010959 -0.006008  0.026455 -0.007964
#
# [159 rows x 11 columns]

# %%
merge_normalized.describe()
# Out:
#              2011        2012        2013        2014        2015        2016  \
# count  159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean     0.000807   -0.000481   -0.001088    0.001711    0.002743    0.003051
# std      0.013153    0.018593    0.014074    0.013849    0.013448    0.015497
# min     -0.038405   -0.055363   -0.090239   -0.043436   -0.056483   -0.091196
# 25%     -0.006641   -0.009506   -0.007648   -0.006557   -0.004502   -0.005383
# 50%     -0.000478   -0.001341   -0.001764    0.001069    0.002713    0.002334
# 75%      0.006541    0.006387    0.007793    0.009807    0.009787    0.012902
# max      0.046848    0.121861    0.037608    0.058866    0.042778    0.044889
#
#              2017        2018        2019        2020        2021
# count  159.000000  159.000000  159.000000  159.000000  159.000000
# mean     0.005022    0.005354    0.006368   -0.007067    0.006701
# std      0.013095    0.012929    0.013484    0.056930    0.014345
# min     -0.024615   -0.034276   -0.037888   -0.231706   -0.045771
# 25%     -0.004382   -0.001483   -0.001207   -0.023594   -0.001695
# 50%      0.004062    0.004317    0.005003    0.003380    0.004999
# 75%      0.012842    0.012737    0.013317    0.020902    0.014320
# max      0.044237    0.039391    0.041998    0.133705    0.053610

# %%
# Top 10 Counties
merge_normalized['2021'].nlargest(n=10)
# Out:
# County
# Dawson County     0.053610
# Long County       0.053110
# Jackson County    0.046590
# Jasper County     0.043722
# Bryan County      0.043090
# Barrow County     0.032097
# Union County      0.030485
# Forsyth County    0.029353
# Pike County       0.028624
# Lamar County      0.028571
# Name: 2021, dtype: float64

# %%
#Bottom 10 Counties
merge_normalized.nsmallest(n=10, columns=['2021'])
# Out:
#                           2011      2012      2013      2014      2015  \
# County
# Chattahoochee County  0.007599  0.090772 -0.001790 -0.043436 -0.056483
# Dooly County         -0.016162 -0.013415 -0.002844 -0.008697 -0.015090
# Terrell County       -0.014173 -0.017572 -0.006287 -0.009381 -0.007158
# Early County         -0.017482 -0.013900 -0.009210 -0.008726  0.000765
# Twiggs County        -0.016364 -0.031236 -0.004439 -0.014433 -0.005477
# Randolph County      -0.012780 -0.034346 -0.014774  0.015690 -0.022146
# Schley County         0.004582 -0.003966  0.014334  0.018449  0.003662
# Treutlen County      -0.010012 -0.005276 -0.014881  0.018995 -0.000881
# Burke County          0.007283 -0.019521 -0.009630 -0.008891  0.000663
# Grady County          0.003037  0.007170 -0.006447  0.004618 -0.005151
#
#                           2016      2017      2018      2019      2020  \
# County
# Chattahoochee County -0.091196  0.013115  0.034422  0.041998 -0.137294
# Dooly County         -0.011615 -0.012689  0.001753 -0.023181 -0.168507
# Terrell County       -0.015861 -0.019723 -0.011152 -0.003255  0.067654
# Early County         -0.014246  0.000291 -0.005624 -0.007704  0.062598
# Twiggs County        -0.010775  0.000605 -0.010764 -0.001834 -0.021803
# Randolph County      -0.000419 -0.024615 -0.021222 -0.002930 -0.063033
# Schley County        -0.005568  0.011006 -0.004584  0.008058 -0.136277
# Treutlen County      -0.012781  0.004613  0.004296  0.011799 -0.068513
# Burke County         -0.000265 -0.003755 -0.002306 -0.000178  0.094413
# Grady County         -0.008404 -0.005342 -0.001292 -0.005742  0.066415
#
#                           2021
# County
# Chattahoochee County -0.045771
# Dooly County         -0.023066
# Terrell County       -0.020649
# Early County         -0.017941
# Twiggs County        -0.016278
# Randolph County      -0.014113
# Schley County        -0.013222
# Treutlen County      -0.013146
# Burke County         -0.012631
# Grady County         -0.011556

# %%
# This gives us a good visual
merge_normalized = merge_normalized.sort_values(by=['2021'])

# %%
merge_pretty = merge_normalized.style.format({
    '2011': '{:,.2%}'.format,'2012': '{:,.2%}'.format,'2013': '{:,.2%}'.format,
    '2014': '{:,.2%}'.format,'2015': '{:,.2%}'.format,'2016': '{:,.2%}'.format,
    '2017': '{:,.2%}'.format,'2018': '{:,.2%}'.format,'2019': '{:,.2%}'.format,
    '2020': '{:,.2%}'.format,'2021': '{:,.2%}'.format,'2019': '{:,.2%}'.format,
    })
merge_pretty
# Out:
# <style type="text/css">
# </style>
# <table id="T_25d58_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >2011</th>
#       <th class="col_heading level0 col1" >2012</th>
#       <th class="col_heading level0 col2" >2013</th>
#       <th class="col_heading level0 col3" >2014</th>
#       <th class="col_heading level0 col4" >2015</th>
#       <th class="col_heading level0 col5" >2016</th>
#       <th class="col_heading level0 col6" >2017</th>
#       <th class="col_heading level0 col7" >2018</th>
#       <th class="col_heading level0 col8" >2019</th>
#       <th class="col_heading level0 col9" >2020</th>
#       <th class="col_heading level0 col10" >2021</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >County</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25d58_level0_row0" class="row_heading level0 row0" >Chattahoochee County</th>
#       <td id="T_25d58_row0_col0" class="data row0 col0" >0.76%</td>
#       <td id="T_25d58_row0_col1" class="data row0 col1" >9.08%</td>
#       <td id="T_25d58_row0_col2" class="data row0 col2" >-0.18%</td>
#       <td id="T_25d58_row0_col3" class="data row0 col3" >-4.34%</td>
#       <td id="T_25d58_row0_col4" class="data row0 col4" >-5.65%</td>
#       <td id="T_25d58_row0_col5" class="data row0 col5" >-9.12%</td>
#       <td id="T_25d58_row0_col6" class="data row0 col6" >1.31%</td>
#       <td id="T_25d58_row0_col7" class="data row0 col7" >3.44%</td>
#       <td id="T_25d58_row0_col8" class="data row0 col8" >4.20%</td>
#       <td id="T_25d58_row0_col9" class="data row0 col9" >-13.73%</td>
#       <td id="T_25d58_row0_col10" class="data row0 col10" >-4.58%</td>
#     </tr>
#     <tr>
#       <th id="T_25d58_level0_row1" class="row_heading level0 row1" >Dooly County</th>
#       <td id="T_25d58_row1_col0" class="data row1 col0" >-1.62%</td>
#       <td id="T_25d58_row1_col1" class="data row1 col1" >-1.34%</td>
#       <td id="T_25d58_row1_col2" class="data row1 col2" >-0.28%</td>
#       <td id="T_25d58_row1_col3" class="data row1 col3" >-0.87%</td>
#       <td id="T_25d58_row1_col4" class="data row1 col4" >-1.51%</td>
#       <td id="T_25d58_row1_col5" class="data row1 col5" >-1.16%</td>
#       <td id="T_25d58_row1_col6" class="data row1 col6" >-1.27%</td>
#       <td id="T_25d58_row1_col7" class="data row1 col7" >0.18%</td>
#       <td id="T_25d58_row1_col8" class="data row1 col8" >-2.32%</td>
#       <td id="T_25d58_row1_col9" class="data row1 col9" >-16.85%</td>
#       <td id="T_25d58_row1_col10" class="data row1 col10" >-2.31%</td>
#     </tr>
#     <tr>
#       <th id="T_25d58_level0_row2" class="row_heading level0 row2" >Terrell County</th>
#       <td id="T_25d58_row5_col4" class="data row5 col4" >-2.21%</td>
#       <td id="T_25d58_row5_col5" class="data row5 col5" >-0.04%</td>
#       <td id="T_25d58_row5_col6" class="data row5 col6" >-2.46%</td>
#       <td id="T_25d58_row5_col7" class="data row5 col7" >-2.12%</td>
#       <td id="T_25d58_row5_col8" class="data row5 col8" >-0.29%</td>
#       <td id="T_25d58_row5_col9" class="data row5 col9" >-6.30%</td>
#       <td id="T_25d58_row5_col10" class="data row5 col10" >-1.41%</td>
#     </tr>
#     <tr>
#       <th id="T_25d58_level0_row6" class="row_heading level0 row6" >Schley County</th>
#       <td id="T_25d58_row6_col0" class="data row6 col0" >0.46%</td>
#       <td id="T_25d58_row6_col1" class="data row6 col1" >-0.40%</td>
#       <td id="T_25d58_row6_col2" class="data row6 col2" >1.43%</td>
#       <td id="T_25d58_row6_col3" class="data row6 col3" >1.84%</td>
#       <td id="T_25d58_row6_col4" class="data row6 col4" >0.37%</td>
#       <td id="T_25d58_row6_col5" class="data row6 col5" >-0.56%</td>
#       <td id="T_25d58_row6_col6" class="data row6 col6" >1.10%</td>
#       <td id="T_25d58_row6_col7" class="data row6 col7" >-0.46%</td>
#       <td id="T_25d58_row6_col8" class="data row6 col8" >0.81%</td>
#       <td id="T_25d58_row6_col9" class="data row6 col9" >-13.63%</td>
#       <td id="T_25d58_row6_col10" class="data row6 col10" >-1.32%</td>
#     </tr>
#     <tr>
#       <th id="T_25d58_level0_row7" class="row_heading level0 row7" >Treutlen County</th>
#       <td id="T_25d58_row7_col0" class="data row7 col0" >-1.00%</td>
#       <td id="T_25d58_row7_col1" class="data row7 col1" >-0.53%</td>
#       <td id="T_25d58_row7_col2" class="data row7 col2" >-1.49%</td>
#       <td id="T_25d58_row7_col3" class="data row7 col3" >1.90%</td>
#       <td id="T_25d58_row7_col4" class="data row7 col4" >-0.09%</td>
#       <td id="T_25d58_row7_col5" class="data row7 col5" >-1.28%</td>
#       <td id="T_25d58_row7_col6" class="data row7 col6" >0.46%</td>
#       <td id="T_25d58_row7_col7" class="data row7 col7" >0.43%</td>
#       <td id="T_25d58_row7_

# %%
samples_df = merge_normalized.sample(10)
samples_df
# Out:
#                        2011      2012      2013      2014      2015      2016  \
# County
# Calhoun County    -0.010751 -0.008604  0.004568 -0.012883  0.003531 -0.027081
# Candler County     0.016889 -0.009733 -0.012624 -0.008858  0.001014 -0.002485
# Wilkinson County  -0.012070  0.007224 -0.012657 -0.008332 -0.021868 -0.006498
# Meriwether County -0.010130 -0.012271 -0.005485 -0.000613 -0.001604 -0.005433
# Worth County      -0.008114 -0.007436 -0.013954 -0.002279 -0.015136  0.001933
# Pulaski County    -0.011177 -0.011725 -0.011779 -0.005010 -0.009635 -0.009904
# Grady County       0.003037  0.007170 -0.006447  0.004618 -0.005151 -0.008404
# Towns County       0.004368 -0.001607  0.021212  0.027541  0.011461  0.018558
# Ben Hill County   -0.003060  0.000739 -0.008348  0.000057 -0.005383 -0.005815
# Lee County         0.005912  0.004653  0.011735  0.002891  0.001785  0.000411
#
#                        2017      2018      2019      2020      2021
# County
# Calhoun County     0.005347 -0.008290 -0.024606 -0.100906 -0.009173
# Candler County    -0.012826  0.010750  0.002035  0.015321  0.003272
# Wilkinson County  -0.007538  0.005808 -0.007662 -0.010295 -0.001470
# Meriwether County -0.001948  0.002380  0.002422 -0.023352  0.008439
# Worth County      -0.009647 -0.010959 -0.006008  0.026455 -0.007964
# Pulaski County    -0.008764 -0.010539  0.007401 -0.116298  0.005475
# Grady County      -0.005342 -0.001292 -0.005742  0.066415 -0.011556
# Towns County       0.012351  0.024833  0.013931  0.044134  0.026796
# Ben Hill County   -0.012046 -0.015534 -0.004942  0.026450  0.000291
# Lee County         0.007739  0.011383  0.009441  0.104310  0.006992

# %%
merge_normalized
# Out:
#                       2011      2012      2013      2014      2015      2016  \
# County
# Appling County    0.006653 -0.004171 -0.000816  0.005553 -0.002653  0.001249
# Atkinson County  -0.000478 -0.012561  0.001090 -0.006293  0.014615 -0.004561
# Bacon County      0.007955  0.000179  0.001973  0.000358  0.004205  0.003831
# Baker County     -0.034975  0.017819 -0.007122 -0.017633 -0.028902 -0.002193
# Baldwin County   -0.011487  0.029749 -0.007115 -0.005867 -0.007709 -0.006716
# ...                    ...       ...       ...       ...       ...       ...
# Whitfield County  0.001645  0.000165 -0.002283  0.003389  0.005648  0.006688
# Wilcox County    -0.006979 -0.019356 -0.001654 -0.013806  0.009632 -0.020078
# Wilkes County    -0.015305 -0.013392 -0.016051  0.002920 -0.003313 -0.011988
# Wilkinson County -0.012070  0.007224 -0.012657 -0.008332 -0.021868 -0.006498
# Worth County     -0.008114 -0.007436 -0.013954 -0.002279 -0.015136  0.001933
#
#                       2017      2018      2019      2020      2021
# County
# Appling County    0.000217  0.004933 -0.008038  0.002121  0.003256
# Atkinson County  -0.004341  0.010537 -0.008988  0.003870  0.010842
# Bacon County     -0.005680 -0.009639  0.000180  0.002253 -0.003956
# Baker County     -0.008477 -0.021849 -0.013597 -0.066623 -0.008790
# Baldwin County   -0.005899  0.000178  0.000111 -0.027396  0.000183
# ...                    ...       ...       ...       ...       ...
# Whitfield County -0.002186  0.000221  0.001498 -0.014751  0.001178
# Wilcox County    -0.006113  0.000456 -0.020150  0.014407  0.000916
# Wilkes County     0.006117 -0.002331 -0.007720 -0.021804 -0.004500
# Wilkinson County -0.007538  0.005808 -0.007662 -0.010295 -0.001470
# Worth County     -0.009647 -0.010959 -0.006008  0.026455 -0.007964
#
# [159 rows x 11 columns]

# %%
# merge_census['Type'] = 'Rural'
# merge_census.loc[merge_census['2020'] > 50000, 'Type'] = 'Urban'
merge_urban = merge_normalized.loc[merge_normalized['2020'] > 50000, :]
merge_rural = merge_normalized.loc[merge_normalized['2020'] < 50000, :]
# merge_census

# %%
merge_urban
# Out:
# Empty DataFrame
# Columns: [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
# Index: []

# %%
plt.plot(samples_df.T);
plt.legend(samples_df.index,loc="lower left")
plt.show()

# %%
plt.plot(samples_df.T);
plt.legend(samples_df.index,loc="lower left")
plt.yscale('log')
plt.show()
